# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('position_salaries.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  10 non-null     object
#  1   Level     10 non-null     int64
#  2   Salary    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %%
x = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, 2].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test, = train_test_split(x, y, test_size = 0.2, random_state=0)
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(x, y)
# Out:
# LinearRegression()

# %%
def viz_linear():
    plt.scatter(x, y, color='red')
    plt.plot(x, lin_reg.predict(x), color='blue')
    plt.title('Linear Regression without Polynomial')
    plt.xlabel('Position Level')
    plt.ylabel('Salary')
    plt.show()
    return

# %%
viz_linear()

# %%
## Here we apply Polynomial On It

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
x_poly = poly_reg.fit_transform(x)
poly_reg = LinearRegression()
poly_reg.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression



# Create polynomial features.............
poly_features = PolynomialFeatures(degree=4)
x_poly = poly_features.fit_transform(x)

# Create and fit polynomial regression model
poly_reg = LinearRegression()
poly_reg.fit(x_poly, y)

def viz_polynomial():
    plt.figure(figsize=(10, 6))
    plt.scatter(x, y, color='red', s=100, label='Actual Data')
    
    # Create smoother line for better visualization................
    x_plot = np.linspace(x.min(), x.max(), 100).reshape(-1, 1)
    x_plot_poly = poly_features.transform(x_plot)
    y_pred = poly_reg.predict(x_plot_poly)
    
    plt.plot(x_plot, y_pred, color='blue', linewidth=2, label='Polynomial Regression (Degree 4)')
    plt.title('Polynomial Regression (Degree 4)', fontsize=14, fontweight='bold')
    plt.xlabel('Position Level', fontsize=12)
    plt.ylabel('Salary', fontsize=12)
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.show()

# Call the visualization function.....................
viz_polynomial()

# Optional: Print model metrics......................
y_pred = poly_reg.predict(x_poly)
mse = np.mean((y - y_pred) ** 2)
r2 = poly_reg.score(x_poly, y)

print(f"Polynomial Regression (Degree 4) Results:")
print(f"Mean Squared Error: {mse:.2f}")
print(f"R-squared Score: {r2:.4f}")
# Out:
# Polynomial Regression (Degree 4) Results:
# Mean Squared Error: 210343822.84
# R-squared Score: 0.9974

# %%
lin_reg.predict([[5.5]])
# Out:
# array([249500.])

# %%
pol_reg.predict(poly_reg.fit_transform([[5.5]]))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 pol_reg.predict(poly_reg.fit_transform([[5.5]]))
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# --> 286     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:267, in LinearModel._decision_function(self, X)
#     266 def _decision_function(self, X):
# --> 267     check_is_fitted(self)
#     269     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     270     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...
