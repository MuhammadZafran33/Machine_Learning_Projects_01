# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('online_gaming_behavior_dataset.csv')

# %%
df.head()
# Out:
#    PlayerID  Age  Gender Location GameGenre  PlayTimeHours  InGamePurchases  \
# 0      9000   43    Male    Other  Strategy      16.271119                0
# 1      9001   29  Female      USA  Strategy       5.525961                0
# 2      9002   22  Female      USA    Sports       8.223755                0
# 3      9003   35    Male      USA    Action       5.265351                1
# 4      9004   33    Male   Europe    Action      15.531945                0
#
#   GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# 0         Medium                6                        108           79
# 1         Medium                5                        144           11
# 2           Easy               16                        142           35
# 3           Easy                9                         85           57
# 4         Medium                2                        131           95
#
#    AchievementsUnlocked EngagementLevel
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40034 entries, 0 to 40033
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PlayerID                   40034 non-null  int64
#  1   Age                        40034 non-null  int64
#  2   Gender                     40034 non-null  object
#  3   Location                   40034 non-null  object
#  4   GameGenre                  40034 non-null  object
#  5   PlayTimeHours              40034 non-null  float64
#  6   InGamePurchases            40034 non-null  int64
#  7   GameDifficulty             40034 non-null  object
#  8   SessionsPerWeek            40034 non-null  int64
#  9   AvgSessionDurationMinutes  40034 non-null  int64
#  10  PlayerLevel                40034 non-null  int64
#  11  AchievementsUnlocked       40034 non-null  int64
#  12  EngagementLevel            40034 non-null  object
# ...

# %%
gender = pd.get_dummies(df['Gender'], drop_first=True)
df = pd.concat([df, gender], axis=1)

# %%
df.drop(['Gender'], axis=1, inplace=True)

# %%
# Check the actual column names in your DataFrame
print(df.columns)

# After seeing the actual column names, use the correct column name
# The error shows 'EstimatedSalary' doesn't exist, so we need to use columns that actually exist
# This is a placeholder - you'll need to replace with actual column names from your DataFrame
actual_columns = list(df.columns)  # Get all available columns

# Choose columns that exist in your DataFrame
# For example, if your DataFrame has columns like 'Age', 'Salary' (not 'EstimatedSalary'), and 'Gender'
if 'Age' in df.columns and 'Salary' in df.columns and 'Male' in df.columns:
    X = df[['Age', 'Salary', 'Male']]
elif len(actual_columns) >= 3:  # If we have at least 3 columns, use the first 3 for demonstration
    X = df[actual_columns[:3]]  # Use first 3 columns
    print(f"Using columns {actual_columns[:3]} for X")
else:
    # If we have fewer columns, use what's available
    X = df[actual_columns]
    print(f"Using all available columns for X: {actual_columns}")

# For the target variable, check if 'Purchased' exists
if 'Purchased' in df.columns:
    y = df['Purchased']
else:
    # If 'Purchased' doesn't exist, use the last column as target (common practice)
    y = df[actual_columns[-1]]
    print(f"'Purchased' column not found. Using {actual_columns[-1]} as target variable.")
# Out:
# Index(['PlayerID', 'Age', 'Location', 'GameGenre', 'PlayTimeHours',
#        'InGamePurchases', 'GameDifficulty', 'SessionsPerWeek',
#        'AvgSessionDurationMinutes', 'PlayerLevel', 'AchievementsUnlocked',
#        'EngagementLevel', 'Male'],
#       dtype='object')
# Using columns ['PlayerID', 'Age', 'Location'] for X
# 'Purchased' column not found. Using Male as target variable.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Assuming X is your dataframe with mixed data types
# Step 1: Identify numerical and categorical columns
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = X.select_dtypes(include=['object', 'category']).columns

# Step 2: Apply StandardScaler only to numerical columns
scaler = StandardScaler()
X_scaled_numerical = scaler.fit_transform(X[numerical_cols])

# Step 3: Convert back to DataFrame to maintain column names
X_scaled_numerical_df = pd.DataFrame(X_scaled_numerical, columns=numerical_cols, index=X.index)

# Step 4: If you need to keep categorical columns, you can one-hot encode them
# and then combine with scaled numerical data
# For example:
# X_categorical = pd.get_dummies(X[categorical_cols])
# X_processed = pd.concat([X_scaled_numerical_df, X_categorical], axis=1)

# If you just want to work with the numerical data:
X_processed = X_scaled_numerical_df

# %%
# Option 1: Make sure to use the same features for fit and transform
# First, ensure X has the same columns as what was used during fit
X_without_location = X.drop(columns=['Location'])  # Remove the column that wasn't in the fit data
scaled_features = scaler.transform(X_without_location)

# Option 2: If you need to include the Location feature, refit the scaler
# scaler.fit(X)  # Refit the scaler with all current features
# scaled_features = scaler.transform(X)

# Option 3: If you need to ensure consistent feature sets
# Define features to use before fitting
# features_to_use = ['feature1', 'feature2', ...]  # List all features except 'Location'
# scaler.fit(X[features_to_use])
# scaled_features = scaler.transform(X[features_to_use])

# %%
scaled_features
# Out:
# array([[-1.73200754,  1.09602286],
#        [-1.73192101, -0.29796885],
#        [-1.73183449, -0.9949647 ],
#        ...,
#        [ 1.73183449, -1.69196056],
#        [ 1.73192101,  0.19988533],
#        [ 1.73200754, -1.29367721]])

# %%
# First, import the necessary scaling function from sklearn
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

# Define a function to scale only numeric columns
def scale_numeric_columns(X):
    # Create a copy of the dataframe to avoid modifying the original
    X_copy = X.copy()
    
    # Identify numeric columns
    numeric_columns = X_copy.select_dtypes(include=[np.number]).columns
    
    # Apply scaling only to numeric columns
    scaler = StandardScaler()
    X_copy[numeric_columns] = scaler.fit_transform(X_copy[numeric_columns])
    
    return X_copy

# Apply the function to scale only numeric columns
scaled_df = scale_numeric_columns(X)

# Now all columns are preserved, with only numeric ones being scaled
print(f"scaled_df shape: {scaled_df.shape}")
print(f"X.columns length: {len(X.columns)}")

# No need to create a new DataFrame since we already have one with all columns
df_feat = scaled_df

# Alternative approach if you want to scale only specific columns:
# numeric_columns = X.select_dtypes(include=[np.number]).columns
# scaler = StandardScaler()
# X_scaled = X.copy()
# X_scaled[numeric_columns] = scaler.fit_transform(X[numeric_columns])
# df_feat = X_scaled
# Out:
# scaled_df shape: (40034, 3)
# X.columns length: 3

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_features, y, test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
confusion_matrix(y_test, pred)
# Out:
# array([[1284, 1905],
#        [1883, 2935]], dtype=int64)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.41      0.40      0.40      3189
#         True       0.61      0.61      0.61      4818
#
#     accuracy                           0.53      8007
#    macro avg       0.51      0.51      0.51      8007
# weighted avg       0.53      0.53      0.53      8007
